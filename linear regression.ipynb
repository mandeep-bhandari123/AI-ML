# %%
import numpy as np
import matplotlib.pyplot as pit
pit.style.use("./deeplearning.mplstyle")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300, 500])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = len(x_train)
print(f"Number of traning example is: {m}")

# %% [markdown]
# ![image.png](attachment:image.png)
